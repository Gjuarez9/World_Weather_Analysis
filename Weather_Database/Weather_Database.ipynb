# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import json 

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lugovskoy
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | bozoum
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | la ronge
# Processing Record 9 of Set 1 | talnakh
# Processing Record 10 of Set 1 | povenets
# Processing Record 11 of Set 1 | torquay
# Processing Record 12 of Set 1 | omboue
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | narsaq
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | sao joao da barra
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | chapais
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 1 | wajir
# Processing Record 23 of Set 1 | cherskiy
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | the valley
# Processing Record 27 of Set 1 | kirakira
# Processing Record 28 of Set 1 | serov
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | zachagansk
# City not found. Skipping...
# Processing Record 31 of Set 1 | vila
# Processing Record 32 of Set 1 | kosh-agach
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | eyrarbakki
# Processing Record 35 of Set 1 | roma
# Processing Record 36 of Set 1 | ixtapa
# Processing Record 37 of Set 1 | san patricio
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | puerto del rosario
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | ostrovnoy
# Processing Record 42 of Set 1 | sitka
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | aragarcas
# Processing Record 47 of Set 1 | dabakala
# Processing Record 48 of Set 1 | urfa
# City not found. Skipping...
# Processing Record 49 of Set 1 | katsuura
# Processing Record 50 of Set 1 | yanam
# Processing Record 1 of Set 2 | mkokotoni
# Processing Record 2 of Set 2 | verkhnyaya sinyachikha
# Processing Record 3 of Set 2 | batamshinskiy
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | pitsunda
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | amahai
# Processing Record 8 of Set 2 | port hedland
# Processing Record 9 of Set 2 | buala
# Processing Record 10 of Set 2 | faanui
# Processing Record 11 of Set 2 | deer lake
# Processing Record 12 of Set 2 | marsa matruh
# Processing Record 13 of Set 2 | buloh kasap
# Processing Record 14 of Set 2 | haverfordwest
# Processing Record 15 of Set 2 | avarua
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | flinders
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | panzhihua
# Processing Record 20 of Set 2 | nieuw amsterdam
# Processing Record 21 of Set 2 | bathsheba
# Processing Record 22 of Set 2 | yurimaguas
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | east london
# Processing Record 25 of Set 2 | karratha
# Processing Record 26 of Set 2 | asau
# Processing Record 27 of Set 2 | makokou
# Processing Record 28 of Set 2 | ulladulla
# Processing Record 29 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 2 | olinda
# Processing Record 31 of Set 2 | burnie
# Processing Record 32 of Set 2 | torbay
# Processing Record 33 of Set 2 | poso
# Processing Record 34 of Set 2 | margate
# Processing Record 35 of Set 2 | sabang
# Processing Record 36 of Set 2 | hofn
# Processing Record 37 of Set 2 | airai
# Processing Record 38 of Set 2 | alofi
# Processing Record 39 of Set 2 | aktash
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | calatayud
# Processing Record 42 of Set 2 | esperance
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | inverness
# Processing Record 45 of Set 2 | ankpa
# Processing Record 46 of Set 2 | cabo san lucas
# Processing Record 47 of Set 2 | albany
# Processing Record 48 of Set 2 | fortuna
# Processing Record 49 of Set 2 | vanimo
# Processing Record 50 of Set 2 | bratsk
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | moose jaw
# Processing Record 3 of Set 3 | situbondo
# Processing Record 4 of Set 3 | isangel
# Processing Record 5 of Set 3 | pangnirtung
# Processing Record 6 of Set 3 | sinnamary
# Processing Record 7 of Set 3 | upernavik
# Processing Record 8 of Set 3 | broken hill
# Processing Record 9 of Set 3 | rawson
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | coihaique
# Processing Record 12 of Set 3 | cidreira
# Processing Record 13 of Set 3 | ferrol
# Processing Record 14 of Set 3 | rio grande
# Processing Record 15 of Set 3 | mahebourg
# Processing Record 16 of Set 3 | richards bay
# Processing Record 17 of Set 3 | semnan
# Processing Record 18 of Set 3 | salinopolis
# Processing Record 19 of Set 3 | hvammstangi
# City not found. Skipping...
# Processing Record 20 of Set 3 | sorland
# Processing Record 21 of Set 3 | hokitika
# Processing Record 22 of Set 3 | maarianhamina
# Processing Record 23 of Set 3 | velsk
# Processing Record 24 of Set 3 | kushiro
# Processing Record 25 of Set 3 | manaure
# Processing Record 26 of Set 3 | guerrero negro
# Processing Record 27 of Set 3 | jamestown
# Processing Record 28 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 3 | nioro
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | bredasdorp
# Processing Record 32 of Set 3 | jacareacanga
# Processing Record 33 of Set 3 | salaga
# Processing Record 34 of Set 3 | matara
# Processing Record 35 of Set 3 | cookshire
# City not found. Skipping...
# Processing Record 36 of Set 3 | vila velha
# Processing Record 37 of Set 3 | beloha
# Processing Record 38 of Set 3 | cape town
# Processing Record 39 of Set 3 | torbat-e jam
# Processing Record 40 of Set 3 | tarbert
# Processing Record 41 of Set 3 | ahipara
# Processing Record 42 of Set 3 | san cristobal
# Processing Record 43 of Set 3 | oranjemund
# Processing Record 44 of Set 3 | shagonar
# Processing Record 45 of Set 3 | tautira
# Processing Record 46 of Set 3 | hobart
# Processing Record 47 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 3 | severo-kurilsk
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | bima
# Processing Record 1 of Set 4 | marystown
# Processing Record 2 of Set 4 | west wendover
# Processing Record 3 of Set 4 | cockburn town
# Processing Record 4 of Set 4 | ouadda
# Processing Record 5 of Set 4 | north bend
# Processing Record 6 of Set 4 | naron
# Processing Record 7 of Set 4 | uzumlu
# City not found. Skipping...
# Processing Record 8 of Set 4 | nieuw nickerie
# Processing Record 9 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 10 of Set 4 | san pedro
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | akyab
# Processing Record 13 of Set 4 | saint-pierre
# Processing Record 14 of Set 4 | cedar lake
# Processing Record 15 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 4 | forbes
# Processing Record 17 of Set 4 | lufilufi
# Processing Record 18 of Set 4 | whitehorse
# Processing Record 19 of Set 4 | bollnas
# Processing Record 20 of Set 4 | russell
# Processing Record 21 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 4 | nishihara
# Processing Record 23 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 24 of Set 4 | codrington
# Processing Record 25 of Set 4 | aklavik
# Processing Record 26 of Set 4 | abha
# Processing Record 27 of Set 4 | arraial do cabo
# Processing Record 28 of Set 4 | chokurdakh
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | aripuana
# Processing Record 31 of Set 4 | vung tau
# Processing Record 32 of Set 4 | frome
# Processing Record 33 of Set 4 | druzhba
# Processing Record 34 of Set 4 | viedma
# Processing Record 35 of Set 4 | dekoa
# City not found. Skipping...
# Processing Record 36 of Set 4 | la palma
# Processing Record 37 of Set 4 | barrow
# Processing Record 38 of Set 4 | palu
# Processing Record 39 of Set 4 | georgetown
# Processing Record 40 of Set 4 | coari
# Processing Record 41 of Set 4 | seymchan
# Processing Record 42 of Set 4 | saint-philippe
# Processing Record 43 of Set 4 | saint george
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | muyezerskiy
# Processing Record 46 of Set 4 | constitucion
# Processing Record 47 of Set 4 | ponta do sol
# Processing Record 48 of Set 4 | iqaluit
# Processing Record 49 of Set 4 | dolores
# Processing Record 50 of Set 4 | brae
# Processing Record 1 of Set 5 | chapada dos guimaraes
# Processing Record 2 of Set 5 | castro
# Processing Record 3 of Set 5 | ilmajoki
# Processing Record 4 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 5 | parkes
# Processing Record 6 of Set 5 | amarante do maranhao
# Processing Record 7 of Set 5 | balykshi
# Processing Record 8 of Set 5 | tiksi
# Processing Record 9 of Set 5 | port shepstone
# Processing Record 10 of Set 5 | navahrudak
# Processing Record 11 of Set 5 | port elizabeth
# Processing Record 12 of Set 5 | santa cruz
# Processing Record 13 of Set 5 | hendek
# Processing Record 14 of Set 5 | waipawa
# Processing Record 15 of Set 5 | mantua
# Processing Record 16 of Set 5 | krasnoselkup
# Processing Record 17 of Set 5 | bani walid
# Processing Record 18 of Set 5 | conceicao do araguaia
# Processing Record 19 of Set 5 | wembley
# Processing Record 20 of Set 5 | faya
# Processing Record 21 of Set 5 | plettenberg bay
# Processing Record 22 of Set 5 | tigil
# Processing Record 23 of Set 5 | ustynivka
# Processing Record 24 of Set 5 | arrifes
# Processing Record 25 of Set 5 | tuktoyaktuk
# Processing Record 26 of Set 5 | lanigan
# Processing Record 27 of Set 5 | opuwo
# Processing Record 28 of Set 5 | mar del plata
# Processing Record 29 of Set 5 | zhezkazgan
# Processing Record 30 of Set 5 | wanaka
# Processing Record 31 of Set 5 | bairiki
# Processing Record 32 of Set 5 | salalah
# Processing Record 33 of Set 5 | kahului
# Processing Record 34 of Set 5 | saldanha
# Processing Record 35 of Set 5 | killam
# Processing Record 36 of Set 5 | tromso
# Processing Record 37 of Set 5 | jerome
# Processing Record 38 of Set 5 | coquimbo
# Processing Record 39 of Set 5 | quixeramobim
# Processing Record 40 of Set 5 | poum
# Processing Record 41 of Set 5 | kuytun
# Processing Record 42 of Set 5 | maniitsoq
# Processing Record 43 of Set 5 | mabaruma
# Processing Record 44 of Set 5 | tasiilaq
# Processing Record 45 of Set 5 | we
# City not found. Skipping...
# Processing Record 46 of Set 5 | hovd
# Processing Record 47 of Set 5 | shilka
# Processing Record 48 of Set 5 | seoul
# Processing Record 49 of Set 5 | rundu
# Processing Record 50 of Set 5 | komsomolskiy
# Processing Record 1 of Set 6 | hithadhoo
# Processing Record 2 of Set 6 | sechura
# Processing Record 3 of Set 6 | kodinsk
# Processing Record 4 of Set 6 | orlik
# Processing Record 5 of Set 6 | melilla
# Processing Record 6 of Set 6 | caravelas
# Processing Record 7 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 6 | laguna
# Processing Record 9 of Set 6 | santa maria
# Processing Record 10 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 6 | belaya gora
# Processing Record 12 of Set 6 | alice springs
# Processing Record 13 of Set 6 | benguela
# Processing Record 14 of Set 6 | dhidhdhoo
# Processing Record 15 of Set 6 | high rock
# Processing Record 16 of Set 6 | nemuro
# Processing Record 17 of Set 6 | manbij
# Processing Record 18 of Set 6 | pauini
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | karpathos
# Processing Record 21 of Set 6 | grand gaube
# Processing Record 22 of Set 6 | garowe
# Processing Record 23 of Set 6 | salisbury
# Processing Record 24 of Set 6 | khash
# Processing Record 25 of Set 6 | naze
# Processing Record 26 of Set 6 | matagami
# Processing Record 27 of Set 6 | nanortalik
# Processing Record 28 of Set 6 | izumo
# Processing Record 29 of Set 6 | haizhou
# Processing Record 30 of Set 6 | husavik
# Processing Record 31 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 6 | canutama
# Processing Record 33 of Set 6 | chernyshevsk
# Processing Record 34 of Set 6 | lompoc
# Processing Record 35 of Set 6 | karacabey
# Processing Record 36 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 6 | bethel
# Processing Record 38 of Set 6 | veselynove
# Processing Record 39 of Set 6 | souillac
# Processing Record 40 of Set 6 | tuyen quang
# Processing Record 41 of Set 6 | saskylakh
# Processing Record 42 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 43 of Set 6 | kloulklubed
# Processing Record 44 of Set 6 | meulaboh
# Processing Record 45 of Set 6 | awbari
# Processing Record 46 of Set 6 | hailin
# Processing Record 47 of Set 6 | arlit
# Processing Record 48 of Set 6 | mokhsogollokh
# Processing Record 49 of Set 6 | tayga
# Processing Record 50 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 7 | ivanava
# Processing Record 2 of Set 7 | hambantota
# Processing Record 3 of Set 7 | iracoubo
# Processing Record 4 of Set 7 | gunzburg
# Processing Record 5 of Set 7 | harper
# Processing Record 6 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 7 | pangai
# Processing Record 8 of Set 7 | timra
# Processing Record 9 of Set 7 | kalmunai
# Processing Record 10 of Set 7 | gwanda
# Processing Record 11 of Set 7 | vao
# Processing Record 12 of Set 7 | mayor pablo lagerenza
# Processing Record 13 of Set 7 | athabasca
# Processing Record 14 of Set 7 | tabory
# Processing Record 15 of Set 7 | nagod
# Processing Record 16 of Set 7 | ancud
# Processing Record 17 of Set 7 | liuzhou
# Processing Record 18 of Set 7 | montana
# Processing Record 19 of Set 7 | acapulco
# Processing Record 20 of Set 7 | gat
# Processing Record 21 of Set 7 | kodiak
# Processing Record 22 of Set 7 | port lincoln
# Processing Record 23 of Set 7 | storforshei
# Processing Record 24 of Set 7 | kang
# Processing Record 25 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 7 | saint-francois
# Processing Record 27 of Set 7 | libreville
# Processing Record 28 of Set 7 | mahibadhoo
# Processing Record 29 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 30 of Set 7 | lorengau
# Processing Record 31 of Set 7 | logan
# Processing Record 32 of Set 7 | pevek
# Processing Record 33 of Set 7 | gamba
# Processing Record 34 of Set 7 | lazaro cardenas
# Processing Record 35 of Set 7 | turukhansk
# Processing Record 36 of Set 7 | swan river
# Processing Record 37 of Set 7 | palmas
# Processing Record 38 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 39 of Set 7 | phangnga
# Processing Record 40 of Set 7 | raudeberg
# Processing Record 41 of Set 7 | kadnikov
# Processing Record 42 of Set 7 | abnub
# Processing Record 43 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 7 | mpraeso
# Processing Record 45 of Set 7 | brainerd
# Processing Record 46 of Set 7 | maningrida
# Processing Record 47 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 7 | sarakhs
# Processing Record 49 of Set 7 | hailar
# Processing Record 50 of Set 7 | tuatapere
# Processing Record 1 of Set 8 | vardo
# Processing Record 2 of Set 8 | bandarbeyla
# Processing Record 3 of Set 8 | tocopilla
# Processing Record 4 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 8 | marzuq
# Processing Record 6 of Set 8 | otjiwarongo
# Processing Record 7 of Set 8 | manzanillo
# Processing Record 8 of Set 8 | alta gracia
# Processing Record 9 of Set 8 | saint-paul
# Processing Record 10 of Set 8 | sayansk
# Processing Record 11 of Set 8 | dedovichi
# Processing Record 12 of Set 8 | pacific grove
# Processing Record 13 of Set 8 | northam
# Processing Record 14 of Set 8 | lavrentiya
# Processing Record 15 of Set 8 | benghazi
# Processing Record 16 of Set 8 | vostok
# Processing Record 17 of Set 8 | de-kastri
# Processing Record 18 of Set 8 | challapata
# Processing Record 19 of Set 8 | kaitangata
# Processing Record 20 of Set 8 | oranjestad
# Processing Record 21 of Set 8 | dryden
# Processing Record 22 of Set 8 | deputatskiy
# Processing Record 23 of Set 8 | aykhal
# Processing Record 24 of Set 8 | praia da vitoria
# Processing Record 25 of Set 8 | tahoua
# Processing Record 26 of Set 8 | udachnyy
# Processing Record 27 of Set 8 | homer
# Processing Record 28 of Set 8 | gerede
# Processing Record 29 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 8 | lake charles
# Processing Record 31 of Set 8 | buluang
# Processing Record 32 of Set 8 | khandyga
# Processing Record 33 of Set 8 | fairbanks
# Processing Record 34 of Set 8 | leningradskiy
# Processing Record 35 of Set 8 | half moon bay
# Processing Record 36 of Set 8 | kaeo
# Processing Record 37 of Set 8 | burns lake
# Processing Record 38 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 40 of Set 8 | talcahuano
# Processing Record 41 of Set 8 | san jose
# Processing Record 42 of Set 8 | port blair
# Processing Record 43 of Set 8 | sao filipe
# Processing Record 44 of Set 8 | zaysan
# Processing Record 45 of Set 8 | kruisfontein
# Processing Record 46 of Set 8 | saint anthony
# Processing Record 47 of Set 8 | paamiut
# Processing Record 48 of Set 8 | klaksvik
# Processing Record 49 of Set 8 | aranos
# Processing Record 50 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 9 | san andres
# Processing Record 2 of Set 9 | simplicio mendes
# Processing Record 3 of Set 9 | kununurra
# Processing Record 4 of Set 9 | bonthe
# Processing Record 5 of Set 9 | sulina
# Processing Record 6 of Set 9 | vanavara
# Processing Record 7 of Set 9 | upata
# Processing Record 8 of Set 9 | okhotsk
# Processing Record 9 of Set 9 | houma
# Processing Record 10 of Set 9 | namibe
# Processing Record 11 of Set 9 | suntar
# Processing Record 12 of Set 9 | shimoda
# Processing Record 13 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 14 of Set 9 | krasnoarmeysk
# Processing Record 15 of Set 9 | nome
# Processing Record 16 of Set 9 | agadez
# Processing Record 17 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 9 | sattahip
# Processing Record 19 of Set 9 | resende
# Processing Record 20 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 9 | piracanjuba
# Processing Record 22 of Set 9 | flin flon
# Processing Record 23 of Set 9 | khani
# Processing Record 24 of Set 9 | diphu
# Processing Record 25 of Set 9 | coahuayana
# Processing Record 26 of Set 9 | quelimane
# Processing Record 27 of Set 9 | marsh harbour
# Processing Record 28 of Set 9 | mbigou
# Processing Record 29 of Set 9 | mahon
# Processing Record 30 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 9 | terra nova
# Processing Record 32 of Set 9 | serenje
# Processing Record 33 of Set 9 | tiznit
# Processing Record 34 of Set 9 | bereslavka
# Processing Record 35 of Set 9 | ilulissat
# Processing Record 36 of Set 9 | maragogi
# Processing Record 37 of Set 9 | kasempa
# Processing Record 38 of Set 9 | katras
# Processing Record 39 of Set 9 | camacha
# Processing Record 40 of Set 9 | skibbereen
# Processing Record 41 of Set 9 | necochea
# Processing Record 42 of Set 9 | kailua
# Processing Record 43 of Set 9 | wadi musa
# Processing Record 44 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 9 | rockhampton
# Processing Record 46 of Set 9 | samarai
# Processing Record 47 of Set 9 | inhambane
# Processing Record 48 of Set 9 | clarence town
# Processing Record 49 of Set 9 | santa isabel
# Processing Record 50 of Set 9 | kuala terengganu
# Processing Record 1 of Set 10 | lasa
# Processing Record 2 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 10 | wanning
# Processing Record 4 of Set 10 | progreso
# Processing Record 5 of Set 10 | loandjili
# Processing Record 6 of Set 10 | rocha
# Processing Record 7 of Set 10 | puerto madero
# Processing Record 8 of Set 10 | biak
# Processing Record 9 of Set 10 | yining
# Processing Record 10 of Set 10 | cap malheureux
# Processing Record 11 of Set 10 | sioux lookout
# Processing Record 12 of Set 10 | nantucket
# Processing Record 13 of Set 10 | iralaya
# Processing Record 14 of Set 10 | comodoro rivadavia
# Processing Record 15 of Set 10 | los llanos de aridane
# Processing Record 16 of Set 10 | novaya zaimka
# Processing Record 17 of Set 10 | broome
# Processing Record 18 of Set 10 | sandakan
# Processing Record 19 of Set 10 | lagoa
# Processing Record 20 of Set 10 | kavaratti
# Processing Record 21 of Set 10 | saurimo
# Processing Record 22 of Set 10 | palmer
# Processing Record 23 of Set 10 | victor harbor
# Processing Record 24 of Set 10 | riyadh
# Processing Record 25 of Set 10 | tuntum
# Processing Record 26 of Set 10 | samatau
# City not found. Skipping...
# Processing Record 27 of Set 10 | matay
# Processing Record 28 of Set 10 | fianga
# City not found. Skipping...
# Processing Record 29 of Set 10 | novyy urengoy
# Processing Record 30 of Set 10 | mahina
# Processing Record 31 of Set 10 | namwala
# Processing Record 32 of Set 10 | troitskoye
# Processing Record 33 of Set 10 | guimar
# Processing Record 34 of Set 10 | changji
# Processing Record 35 of Set 10 | ayan
# Processing Record 36 of Set 10 | avera
# Processing Record 37 of Set 10 | henzada
# City not found. Skipping...
# Processing Record 38 of Set 10 | sabla
# Processing Record 39 of Set 10 | luanda
# Processing Record 40 of Set 10 | maldonado
# Processing Record 41 of Set 10 | nnewi
# Processing Record 42 of Set 10 | hasaki
# Processing Record 43 of Set 10 | clyde river
# Processing Record 44 of Set 10 | fuerte olimpo
# Processing Record 45 of Set 10 | tecoanapa
# Processing Record 46 of Set 10 | bulgan
# Processing Record 47 of Set 10 | angoche
# Processing Record 48 of Set 10 | bonfim
# Processing Record 49 of Set 10 | zambezi
# Processing Record 50 of Set 10 | tornio
# Processing Record 1 of Set 11 | solnechnyy
# Processing Record 2 of Set 11 | southbridge
# Processing Record 3 of Set 11 | dudinka
# Processing Record 4 of Set 11 | morant bay
# Processing Record 5 of Set 11 | conde
# Processing Record 6 of Set 11 | goderich
# Processing Record 7 of Set 11 | manokwari
# Processing Record 8 of Set 11 | fort nelson
# Processing Record 9 of Set 11 | boliqueime
# Processing Record 10 of Set 11 | port augusta
# Processing Record 11 of Set 11 | yatou
# Processing Record 12 of Set 11 | carndonagh
# Processing Record 13 of Set 11 | ordynskoye
# Processing Record 14 of Set 11 | naryan-mar
# Processing Record 15 of Set 11 | presidencia roque saenz pena
# Processing Record 16 of Set 11 | emirdag
# Processing Record 17 of Set 11 | uruzgan
# Processing Record 18 of Set 11 | pietarsaari
# Processing Record 19 of Set 11 | adre
# Processing Record 20 of Set 11 | fukue
# Processing Record 21 of Set 11 | tambul
# City not found. Skipping...
# Processing Record 22 of Set 11 | tacuati
# Processing Record 23 of Set 11 | altayskoye
# Processing Record 24 of Set 11 | alyangula
# Processing Record 25 of Set 11 | tucurui
# Processing Record 26 of Set 11 | mongu
# Processing Record 27 of Set 11 | yar-sale
# Processing Record 28 of Set 11 | yulara
# Processing Record 29 of Set 11 | knyaze-volkonskoye
# Processing Record 30 of Set 11 | erdenet
# Processing Record 31 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 11 | antofagasta
# Processing Record 33 of Set 11 | honjo
# Processing Record 34 of Set 11 | buchanan
# Processing Record 35 of Set 11 | douglas
# Processing Record 36 of Set 11 | presidente epitacio
# Processing Record 37 of Set 11 | ouallam
# Processing Record 38 of Set 11 | melito di porto salvo
# Processing Record 39 of Set 11 | turayf
# Processing Record 40 of Set 11 | cairns
# Processing Record 41 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 11 | lithgow
# Processing Record 43 of Set 11 | nerchinskiy zavod
# Processing Record 44 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 45 of Set 11 | lubumbashi
# Processing Record 46 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 11 | kenai
# Processing Record 48 of Set 11 | manadhoo
# Processing Record 49 of Set 11 | aparecida do taboado
# Processing Record 50 of Set 11 | morondava
# Processing Record 1 of Set 12 | changying
# Processing Record 2 of Set 12 | praxedis guerrero
# Processing Record 3 of Set 12 | kita
# Processing Record 4 of Set 12 | longyearbyen
# Processing Record 5 of Set 12 | abbeville
# Processing Record 6 of Set 12 | south lake tahoe
# Processing Record 7 of Set 12 | ust-tsilma
# Processing Record 8 of Set 12 | huangchuan
# Processing Record 9 of Set 12 | pidhorodne
# Processing Record 10 of Set 12 | san ramon
# Processing Record 11 of Set 12 | waupun
# Processing Record 12 of Set 12 | kousseri
# Processing Record 13 of Set 12 | pangkalanbuun
# Processing Record 14 of Set 12 | phonhong
# Processing Record 15 of Set 12 | olafsvik
# Processing Record 16 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 17 of Set 12 | outlook
# Processing Record 18 of Set 12 | cabra
# Processing Record 19 of Set 12 | yarada
# Processing Record 20 of Set 12 | saint-laurent-du-var
# Processing Record 21 of Set 12 | dong hoi
# Processing Record 22 of Set 12 | shunyi
# Processing Record 23 of Set 12 | bull savanna
# Processing Record 24 of Set 12 | gijon
# Processing Record 25 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 26 of Set 12 | oriximina
# Processing Record 27 of Set 12 | srednekolymsk
# Processing Record 28 of Set 12 | kieta
# Processing Record 29 of Set 12 | tanabe
# Processing Record 30 of Set 12 | octeville
# Processing Record 31 of Set 12 | kavieng
# Processing Record 32 of Set 12 | mogadishu
# Processing Record 33 of Set 12 | lagos
# Processing Record 34 of Set 12 | scarborough
# Processing Record 35 of Set 12 | ranau
# Processing Record 36 of Set 12 | port-de-paix
# City not found. Skipping...
# Processing Record 37 of Set 12 | atraulia
# Processing Record 38 of Set 12 | kozhevnikovo
# Processing Record 39 of Set 12 | montepuez
# Processing Record 40 of Set 12 | akbarpur
# Processing Record 41 of Set 12 | danielskuil
# Processing Record 42 of Set 12 | grindavik
# Processing Record 43 of Set 12 | sortland
# Processing Record 44 of Set 12 | bonavista
# Processing Record 45 of Set 12 | mikkeli
# Processing Record 46 of Set 12 | coos bay
# Processing Record 47 of Set 12 | ende
# Processing Record 48 of Set 12 | te anau
# Processing Record 49 of Set 12 | sambava
# Processing Record 50 of Set 12 | pitimbu
# Processing Record 1 of Set 13 | mackenzie
# Processing Record 2 of Set 13 | ranong
# Processing Record 3 of Set 13 | prince rupert
# Processing Record 4 of Set 13 | kutum
# Processing Record 5 of Set 13 | bamiantong
# Processing Record 6 of Set 13 | canaries
# Processing Record 7 of Set 13 | mumford
# Processing Record 8 of Set 13 | ibiruba
# Processing Record 9 of Set 13 | suhbaatar
# Processing Record 10 of Set 13 | rosetta
# Processing Record 11 of Set 13 | mankera
# Processing Record 12 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 13 | ginda
# Processing Record 14 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record 15 of Set 13 | portland
# Processing Record 16 of Set 13 | tamluk
# Processing Record 17 of Set 13 | manitouwadge
# Processing Record 18 of Set 13 | bardiyah
# Processing Record 19 of Set 13 | zyryanka
# Processing Record 20 of Set 13 | burica
# City not found. Skipping...
# Processing Record 21 of Set 13 | svetlogorsk
# Processing Record 22 of Set 13 | lovozero
# Processing Record 23 of Set 13 | bubaque
# Processing Record 24 of Set 13 | biltine
# Processing Record 25 of Set 13 | high level
# Processing Record 26 of Set 13 | nara
# Processing Record 27 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 13 | urbana
# Processing Record 29 of Set 13 | marsabit
# Processing Record 30 of Set 13 | sangueya
# Processing Record 31 of Set 13 | sobolevo
# Processing Record 32 of Set 13 | santa cruz cabralia
# Processing Record 33 of Set 13 | launceston
# Processing Record 34 of Set 13 | muswellbrook
# Processing Record 35 of Set 13 | inuvik
# Processing Record 36 of Set 13 | innisfail
# Processing Record 37 of Set 13 | kismayo
# Processing Record 38 of Set 13 | wanlaweyn
# Processing Record 39 of Set 13 | silver city
# Processing Record 40 of Set 13 | masyaf
# Processing Record 41 of Set 13 | eenhana
# Processing Record 42 of Set 13 | garden city
# Processing Record 43 of Set 13 | alibag
# Processing Record 44 of Set 13 | dymer
# Processing Record 45 of Set 13 | nyimba
# Processing Record 46 of Set 13 | apatou
# Processing Record 47 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 13 | hobyo
# Processing Record 49 of Set 13 | general roca
# Processing Record 50 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 14 | ekibastuz
# Processing Record 2 of Set 14 | taoudenni
# Processing Record 3 of Set 14 | san policarpo
# Processing Record 4 of Set 14 | marondera
# Processing Record 5 of Set 14 | achacachi
# Processing Record 6 of Set 14 | caranavi
# Processing Record 7 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 8 of Set 14 | mangan
# Processing Record 9 of Set 14 | mogzon
# Processing Record 10 of Set 14 | cedar rapids
# Processing Record 11 of Set 14 | baisha
# Processing Record 12 of Set 14 | port hardy
# Processing Record 13 of Set 14 | lubango
# Processing Record 14 of Set 14 | lapeer
# Processing Record 15 of Set 14 | bundaberg
# Processing Record 16 of Set 14 | monte alegre de minas
# Processing Record 17 of Set 14 | livingston
# Processing Record 18 of Set 14 | nelson bay
# Processing Record 19 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 14 | lincoln
# Processing Record 21 of Set 14 | cayenne
# Processing Record 22 of Set 14 | nicoya
# Processing Record 23 of Set 14 | zyryanovsk
# Processing Record 24 of Set 14 | lowestoft
# Processing Record 25 of Set 14 | qostanay
# Processing Record 26 of Set 14 | huarmey
# Processing Record 27 of Set 14 | jalpan
# Processing Record 28 of Set 14 | leh
# Processing Record 29 of Set 14 | birao
# Processing Record 30 of Set 14 | anadyr
# Processing Record 31 of Set 14 | tuscaloosa
# Processing Record 32 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 33 of Set 14 | jawhar
# Processing Record 34 of Set 14 | haines junction
# Processing Record 35 of Set 14 | labuan
# Processing Record 36 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 14 | oxford
# Processing Record 38 of Set 14 | hun
# Processing Record 39 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 14 | kushmurun
# Processing Record 41 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 14 | patiya
# Processing Record 43 of Set 14 | mount gambier
# Processing Record 44 of Set 14 | kiunga
# Processing Record 45 of Set 14 | ozernovskiy
# Processing Record 46 of Set 14 | bara
# Processing Record 47 of Set 14 | pokhara
# Processing Record 48 of Set 14 | rio gallegos
# Processing Record 49 of Set 14 | abu samrah
# Processing Record 50 of Set 14 | mitu
# Processing Record 1 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 2 of Set 15 | catamarca
# Processing Record 3 of Set 15 | garlasco
# Processing Record 4 of Set 15 | palma campania
# Processing Record 5 of Set 15 | itaituba
# Processing Record 6 of Set 15 | maceio
# Processing Record 7 of Set 15 | kaputa
# Processing Record 8 of Set 15 | vestmannaeyjar
# Processing Record 9 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 10 of Set 15 | new glasgow
# Processing Record 11 of Set 15 | atambua
# Processing Record 12 of Set 15 | wajima
# Processing Record 13 of Set 15 | beringovskiy
# Processing Record 14 of Set 15 | labelle
# Processing Record 15 of Set 15 | sola
# Processing Record 16 of Set 15 | havoysund
# Processing Record 17 of Set 15 | kamenka
# Processing Record 18 of Set 15 | veinticinco de mayo
# Processing Record 19 of Set 15 | carnduff
# Processing Record 20 of Set 15 | sabha
# Processing Record 21 of Set 15 | dzerzhinskoye
# Processing Record 22 of Set 15 | tarabuco
# Processing Record 23 of Set 15 | dano
# Processing Record 24 of Set 15 | gazipur
# Processing Record 25 of Set 15 | khoy
# Processing Record 26 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 15 | bajo baudo
# City not found. Skipping...
# Processing Record 29 of Set 15 | awjilah
# Processing Record 30 of Set 15 | talalayivka
# Processing Record 31 of Set 15 | sur
# Processing Record 32 of Set 15 | atar
# Processing Record 33 of Set 15 | riohacha
# Processing Record 34 of Set 15 | minab
# Processing Record 35 of Set 15 | dwarka
# Processing Record 36 of Set 15 | pedernales
# Processing Record 37 of Set 15 | adrar
# Processing Record 38 of Set 15 | mackay
# Processing Record 39 of Set 15 | nueva gerona
# Processing Record 40 of Set 15 | ibra
# Processing Record 41 of Set 15 | daru
# Processing Record 42 of Set 15 | omis
# Processing Record 43 of Set 15 | rognan
# Processing Record 44 of Set 15 | ushtobe
# Processing Record 45 of Set 15 | stryn
# Processing Record 46 of Set 15 | camapua
# Processing Record 47 of Set 15 | chernyshkovskiy
# Processing Record 48 of Set 15 | kontagora
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 679

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Lugovskoy      RU  56.9585   64.5290     59.94        99          20
# 1      Khatanga      RU  71.9667  102.5000     43.99        78         100
# 2        Bozoum      CF   6.3193   16.3799     68.45        95         100
# 3  Punta Arenas      CL -53.1500  -70.9167     42.12        81         100
# 4   New Norfolk      AU -42.7826  147.0587     49.91        78          99
# 5         Kapaa      US  22.0752 -159.3190     82.11        68          97
# 6         Vaini      TO -21.2000 -175.2000     76.08        87         100
# 7      La Ronge      CA  55.1001 -105.2842     66.76        55          56
# 8       Talnakh      RU  69.4865   88.3972     43.99        74          29
# 9      Povenets      RU  62.8487   34.8262     52.83        93          87
#
#    Wind Speed Current Description
# 0        6.22          few clouds
# 1        6.42     overcast clouds
# 2        4.36     overcast clouds
# 3       12.12     overcast clouds
# 4        1.99          light rain
# 5        8.01     overcast clouds
# 6       14.20     overcast clouds
# 7        9.57       broken clouds
# 8       16.24    scattered clouds
# 9        5.03     overcast clouds

# %%
# Create CSV file of DF
csv_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_file, index_label="City_ID")
